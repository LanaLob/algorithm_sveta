# %% [markdown]
# Шаг 0. Слияние данных

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import os

merged_data = pd.DataFrame()

#years = list(range(2012, 2018))
years = [2011, 2019]
articles = ['105', '107', '111_4']

# для анализа не разделяем по статьям
for year in years:
    data_gas_year = pd.DataFrame()
    if year == 2018:
        continue
    for art in articles:
        data_gas = pd.read_excel(f'Данные_за_все_года/{art}_{year}_cases_texts.xlsx', index_col=0)
        data_gas['year'] = year
        data_gas['source'] = 'ГАС Правосудие'
        data_gas['article'] = art
        data_gas = data_gas[['Субъект РФ', 'ID', 'text', 'year', 'source']]
        data_gas.columns = ['region', 'ID', 'text', 'year', 'source']
        data_gas_year = pd.concat([data_gas_year, data_gas])
    data_mgs = pd.read_excel(f'Данные_за_все_года/MOSGORSUD_texts_{year}.xlsx', index_col=0)
    data_mgs['year'] = year
    data_mgs['source'] = 'Мосгорсуд'
    data_mgs['Субъект РФ'] = 'Москва'
    data_mgs = data_mgs[['Субъект РФ', 'custom_id', 'text', 'year', 'source']]
    data_mgs.columns = ['region', 'ID', 'text', 'year', 'source']
    merged_data = pd.concat([merged_data, data_gas_year, data_mgs])
    merged_data = merged_data.drop_duplicates('ID')
    merged_data = merged_data.set_index('ID')
    merged_data.to_csv(f'Данные_за_все_года/{year}_merged.csv')

# %% [markdown]
# Шаг 1. Отбор только женских дел

# %%
import re

patterns = [
    r'скончалась',
    r'погибш[аеу][йяю]',
    r'смерт[иь]ю? потерпевшей',
    r'смерт[иь]ю? последней',
    r'мертва',
    r'е[её] труп',
    r'труп женщины'
]

def check_patterns(text):
    global patterns
    
    for pattern in patterns:
        if re.search(pattern, text):
            return True
    return False

# %%
#years = list(range(2012, 2018))
#years = [2012]

women_cases_by_year = []

for year in years:
    data = pd.read_csv(f'Данные_за_все_года/{year}_merged.csv')
    data = data[(data['ID'].notna())&(data['text'].notna())].set_index('ID')
    women_cases = data[data['text'].apply(check_patterns)]
    women_cases_by_year.append([year, len(women_cases)])
    print(year, '-', len(women_cases))
    women_cases.to_csv(f'Данные_за_все_года/{year}_women.csv')
res = pd.DataFrame(women_cases_by_year, columns=['год', 'число женских дел'])
display(res)
#res.to_excel('women_cases_dynamics.xlsx')
    #display(women_cases.head(), len(women_cases))
    #print(len(women_cases))
# Out:
# 2011 - 2075
# 2019 - 1419
#     год  число женских дел
# 0  2011               2075
# 1  2019               1419

# %% [markdown]
# #### Шаг 2. Предобработка текстов

# %%
import re
def keep_only_rus(text):    
    new_text = ''
    for symbol in text:
        if re.match(r'[А-я]', symbol) or symbol == ' ':
            new_text += symbol
        else:
            new_text += ' '
    return new_text

def del_double_spaces(text_with_double_spaces):
    while '  ' in text_with_double_spaces:
        text_with_double_spaces = text_with_double_spaces.replace('  ',' ')
    return text_with_double_spaces

import pymystem3
mstem = pymystem3.Mystem()

def lemmatize(raw_text):
    return ''.join(mstem.lemmatize(raw_text)).strip()

import stop_words

stopwords = stop_words.get_stop_words('russian')
stopwords.extend(stop_words.get_stop_words('english'))
stopwords = list(set(stopwords))
stopwords += [
    'фио', 'гггг', 'подсудимый', 'суд',
    'изымать', 'согласно', 'наказание',
    'потерпевший', 'показание', 'судебный',
    'преступление', 'адрес', 'свидетель',
    'свой', 'находиться', 'час', 'ход'
             ]

def del_stopwords(text):
    global stopwords
    new_text = []
    for word in text.split():
        if word not in stopwords and len(word) > 2:
            new_text.append(word)
    return ' '.join(new_text)

# %%
#years = list(range(2012, 2018))
#years = [2012]
for year in years:
    print(year)
    data = pd.read_csv(f'Данные_за_все_года/{year}_women.csv', index_col=0)
    data['text_prep'] = data['text'].str.lower()
    data['text_prep'] = data['text_prep'].apply(keep_only_rus)
    data['text_prep'] = data['text_prep'].apply(del_double_spaces)
    data['text_prep'] = data['text_prep'].apply(lemmatize)
    data['text_prep'] = data['text_prep'].apply(del_stopwords)
    data['text_prep'] = data['text_prep'].apply(del_double_spaces)
    data = data[data['text_prep'].notna()]
    data.to_csv(f'Данные_за_все_года/{year}_women_prep.csv')
# Out:
# 2011
# 2019

# %% [markdown]
# #### Шаг 3. Применение моделей

# %%
import pickle

with open("cvect.pkl", 'rb') as file:
    cvect = pickle.load(file)
    
with open("gbc_dv.pkl", 'rb') as file:
    dv = pickle.load(file)
    
with open("gbc_ipv.pkl", 'rb') as file:
    ipv = pickle.load(file)

# %%
#years = list(range(2012, 2018))
#years = [2012]

prec_dv_model = 0.86
prec_ipv_model = 0.94

dv_by_years = []

for year in years:
    print(year)
    data = pd.read_csv(f'Данные_за_все_года/{year}_women_prep.csv', index_col=0)
    matrix = cvect.transform(data['text_prep'])
    td_matrix = pd.DataFrame(matrix.toarray(), index=data.index, columns=cvect.get_feature_names())
    td_matrix['DV'] = dv.predict(td_matrix)
    dv_preds = td_matrix[['DV']]
    td_matrix_ipv = td_matrix[td_matrix['DV']==1].drop('DV', axis=1)
    td_matrix_ipv['IPV'] = ipv.predict(td_matrix_ipv)
    dv_preds['IPV'] = td_matrix_ipv['IPV']
    dv_by_years.append([
        year, 
        len(data), 
        dv_preds['DV'].sum(),
        dv_preds['DV'].sum()*prec_dv_model,
        dv_preds['IPV'].sum(),
        dv_preds['IPV'].sum()*prec_dv_model*prec_ipv_model
    ])
    dv_preds.to_excel(f'Данные_за_все_года/{year}_women_predictions.xlsx')
dv_by_years_final = pd.DataFrame(dv_by_years, columns = [
    'год', 'число женских дел', 'из них ДН', 'из них ДН (с поправкой на точность)',
    'из них партнерское', 'из них партнерское (с поправкой на точность)'
])
display(dv_by_years_final)
# Out:
# 2011
# 2019
#     год  число женских дел  из них ДН  из них ДН (с поправкой на точность)  \
# 0  2011               2075       1578                              1357.08
# 1  2019               1419       1108                               952.88
#
#    из них партнерское  из них партнерское (с поправкой на точность)
# 0              1356.0                                     1096.1904
# 1               965.0                                      780.1060

# %%
dv_by_years_final['доля ДН (%)'] = dv_by_years_final['из них ДН (с поправкой на точность)'] / dv_by_years_final['число женских дел'] * 100
dv_by_years_final['доля партнерского из ДН (%)'] = dv_by_years_final['из них партнерское (с поправкой на точность)'] / dv_by_years_final['из них ДН (с поправкой на точность)'] * 100
dv_by_years_final
# Out:
#     год  число женских дел  из них ДН  из них ДН (с поправкой на точность)  \
# 0  2011               2075       1578                              1357.08
# 1  2019               1419       1108                               952.88
#
#    из них партнерское  из них партнерское (с поправкой на точность)  \
# 0              1356.0                                     1096.1904
# 1               965.0                                      780.1060
#
#    доля ДН (%)  доля партнерского из ДН (%)
# 0    65.401446                    80.775665
# 1    67.151515                    81.868231

# %%
dv_by_years_final['доля ДН (нижняя граница)'] = 100*(dv_by_years_final['доля ДН (%)']/100 - 1.96* (dv_by_years_final['доля ДН (%)']/100*(1-dv_by_years_final['доля ДН (%)']/100)/dv_by_years_final['число женских дел'])**(1/2))
dv_by_years_final['доля ДН (верхняя граница)'] = 100*(dv_by_years_final['доля ДН (%)']/100 + 1.96* (dv_by_years_final['доля ДН (%)']/100*(1-dv_by_years_final['доля ДН (%)']/100)/dv_by_years_final['число женских дел'])**(1/2))
dv_by_years_final['доля партнерского (нижняя граница)'] = 100*(dv_by_years_final['доля партнерского из ДН (%)']/100 - 1.96* (dv_by_years_final['доля партнерского из ДН (%)']/100*(1-dv_by_years_final['доля партнерского из ДН (%)']/100)/dv_by_years_final['из них ДН (с поправкой на точность)'])**(1/2))
dv_by_years_final['доля партнерского (верхняя граница)'] = 100*(dv_by_years_final['доля партнерского из ДН (%)']/100 + 1.96* (dv_by_years_final['доля партнерского из ДН (%)']/100*(1-dv_by_years_final['доля партнерского из ДН (%)']/100)/dv_by_years_final['из них ДН (с поправкой на точность)'])**(1/2))
dv_by_years_final
# Out:
#     год  число женских дел  из них ДН  из них ДН (с поправкой на точность)  \
# 0  2011               2075       1578                              1357.08
# 1  2019               1419       1108                               952.88
#
#    из них партнерское  из них партнерское (с поправкой на точность)  \
# 0              1356.0                                     1096.1904
# 1               965.0                                      780.1060
#
#    доля ДН (%)  доля партнерского из ДН (%)  доля ДН (нижняя граница)  \
# 0    65.401446                    80.775665                 63.354673
# 1    67.151515                    81.868231                 64.707801
#
#    доля ДН (верхняя граница)  доля партнерского (нижняя граница)  \
# 0                  67.448219                           78.679048
# 1                  69.595230                           79.421903
#
#    доля партнерского (верхняя граница)
# 0                            82.872283
# 1                            84.314559

# %%
#dv_by_years_final.to_excel('Динамика_ДН_по_годам_2011_2019.xlsx')

# %% [markdown]
# #### Шаг 4. Добавление регионов

# %%
years = list(range(2011, 2020))
regions = set()

for year in years:
    if year == 2018:
        continue
    texts = pd.read_csv(f'Данные_за_все_года/{year}_women.csv', index_col=0)
    regions.update(set(texts['region'].replace({'Москва': 'город Москва', 'Город Москва': 'город Москва'}).drop_duplicates()))
len(regions)
# Out:
# 84

# %%
# без поправки на точность

import pandas as pd

years = list(range(2011, 2020))
regions_dynamics = pd.DataFrame(index=regions)

for year in years:
    if year == 2018:
        continue
    texts = pd.read_csv(f'Данные_за_все_года/{year}_women.csv', index_col=0)
    texts['region'] = texts['region'].replace({'Москва': 'город Москва', 'Город Москва': 'город Москва'})
    predictions = pd.read_excel(f'Данные_за_все_года/{year}_women_predictions.xlsx', index_col=0)
    texts[['DV', 'IPV']] = predictions[['DV', 'IPV']]
    #print(year, len(texts), len(predictions))
    #regions_by_year = texts.groupby('region')['DV','IPV'].sum()
    regions_by_year = pd.pivot_table(texts, index='region', values=['DV','IPV'], aggfunc=sum)
    regions_dynamics[[f'DV_{year}', f'IPV_{year}']] = regions_by_year[['DV','IPV']]
    #print(regions_by_year[['DV','IPV']].sum())
    #print(regions_dynamics[[f'DV_{year}', f'IPV_{year}']].sum())
    regions_dynamics[[f'DV_{year}', f'IPV_{year}']] = regions_dynamics[[f'DV_{year}', f'IPV_{year}']].fillna(0)
    
    display(regions_dynamics)
# Out:
#                        DV_2011  IPV_2011
# Иркутская область         27.0      21.0
# Рязанская область          6.0       4.0
# Курская область           17.0      14.0
# Республика Бурятия        32.0      26.0
# Ростовская область        21.0      17.0
# ...                        ...       ...
# Республика Карелия        10.0       9.0
# город Санкт-Петербург     13.0      13.0
# Саратовская область       25.0      24.0
# Кировская область          8.0       6.0
# Республика Мордовия        5.0       5.0
#
# [84 rows x 2 columns]
#                        DV_2011  IPV_2011  DV_2012  IPV_2012
# Иркутская область         27.0      21.0     31.0      25.0
# Рязанская область          6.0       4.0      6.0       6.0
# Курская область           17.0      14.0     10.0       8.0
# Республика Бурятия        32.0      26.0     34.0      27.0
# Ростовская область        21.0      17.0     16.0      15.0
# ...                        ...       ...      ...       ...
# Республика Карелия        10.0       9.0      7.0       6.0
# город Санкт-Петербург     13.0      13.0     13.0      12.0
# Саратовская область       25.0      24.0     38.0      35.0
# Кировская область          8.0       6.0     20.0      17.0
# Республика Мордовия        5.0       5.0      7.0       7.0
#
# [84 rows x 4 columns]
#                        DV_2011  IPV_2011  DV_2012  IPV_2012  DV_2013  IPV_2013
# Иркутская область         27.0      21.0     31.0      25.0     40.0      34.0
# Рязанская область          6.0       4.0      6.0       6.0      4.0       3.0
# Курская область           17.0      14.0     10.0       8.0     17.0      14.0
# Республика Бурятия        32.0      26.0     34.0      27.0     25.0      19.0
# Ростовская область        21.0      17.0     16.0      15.0     31.0      27.0
# ...                        ...       ...      ...       ...      ...       ...
# Республика Карелия        10.0       9.0      7.0       6.0      5.0       4.0
# город Санкт-Петербург     13.0      13.0     13.0      12.0     14.0      11.0
# Саратовская область       25.0      24.0     38.0      35.0     35.0      32.0
# Кировская область          8.0       6.0     20.0      17.0     16.0      12.0
# Республика Мордовия        5.0       5.0      7.0       7.0     12.0      10.0
#
# [84 rows x 6 columns]
#                        DV_2011  IPV_2011  DV_2012  IPV_2012  DV_2013  \
# Иркутская область         27.0      21.0     31.0      25.0     40.0
# Рязанская область          6.0       4.0      6.0       6.0      4.0
# Курская область           17.0      14.0     10.0       8.0     17.0
# Республика Бурятия        32.0      26.0     34.0      27.0     25.0
# Ростовская область        21.0      17.0     16.0      15.0     31.0
# ...                        ...       ...      ...       ...      ...
# Республика Карелия        10.0       9.0      7.0       6.0      5.0
# город Санкт-Петербург     13.0      13.0     13.0      12.0     14.0
# Саратовская область       25.0      24.0     38.0      35.0     35.0
# Кировская область          8.0       6.0     20.0      17.0     16.0
# Республика Мордовия        5.0       5.0      7.0       7.0     12.0
#
#                        IPV_2013  DV_2014  IPV_2014
# Иркутская область          34.0     50.0      43.0
# Рязанская область           3.0      8.0       7.0
# Курская область            14.0     14.0      13.0
# Республика Бурятия         19.0     28.0      25.0
# Ростовская область         27.0     26.0      20.0
# ...                         ...      ...       ...
# Республика Карелия          4.0     16.0      14.0
# город Санкт-Петербург      11.0     18.0      18.0
# Саратовская область        32.0     44.0      40.0
# Кировская область          12.0     30.0      28.0
# Республика Мордовия        10.0      7.0       6.0
#
# [84 rows x 8 columns]
#                        DV_2011  IPV_2011  DV_2012  IPV_2012  DV_2013  \
# Иркутская область         27.0      21.0     31.0      25.0     40.0
# Рязанская область          6.0       4.0      6.0       6.0      4.0
# Курская область           17.0      14.0     10.0       8.0     17.0
# Республика Бурятия        32.0      26.0     34.0      27.0     25.0
# Ростовская область        21.0      17.0     16.0      15.0     31.0
# ...                        ...       ...      ...       ...      ...
# Республика Карелия        10.0       9.0      7.0       6.0      5.0
# город Санкт-Петербург     13.0      13.0     13.0      12.0     14.0
# Саратовская область       25.0      24.0     38.0      35.0     35.0
# Кировская область          8.0       6.0     20.0      17.0     16.0
# Республика Мордовия        5.0       5.0      7.0       7.0     12.0
#
#                        IPV_2013  DV_2014  IPV_2014  DV_2015  IPV_2015
# Иркутская область          34.0     50.0      43.0       52      40.0
# Рязанская область           3.0      8.0       7.0        5       5.0
# Курская область            14.0     14.0      13.0       10       8.0
# Республика Бурятия         19.0     28.0      25.0       30      26.0
# Ростовская область         27.0     26.0      20.0       38      32.0
# ...                         ...      ...       ...      ...       ...
# Республика Карелия          4.0     16.0      14.0       11      10.0
# город Санкт-Петербург      11.0     18.0      18.0       19      19.0
# Саратовская область        32.0     44.0      40.0       29      26.0
# Кировская область          12.0     30.0      28.0       22      20.0
# Республика Мордовия        10.0      7.0       6.0        7       6.0
#
# [84 rows x 10 columns]
#                        DV_2011  IPV_2011  DV_2012  IPV_2012  DV_2013  \
# Иркутская область         27.0      21.0     31.0      25.0     40.0
# Рязанская область          6.0       4.0      6.0       6.0      4.0
# Курская область           17.0      14.0     10.0       8.0     17.0
# Республика Бурятия        32.0      26.0     34.0      27.0     25.0
# Ростовская область        21.0      17.0     16.0      15.0     31.0
# ...                        ...       ...      ...       ...      ...
# Республика Карелия        10.0       9.0      7.0       6.0      5.0
# город Санкт-Петербург     13.0      13.0     13.0      12.0     14.0
# Саратовская область       25.0      24.0     38.0      35.0     35.0
# Кировская область          8.0       6.0     20.0      17.0     16.0
# Республика Мордовия        5.0       5.0      7.0       7.0     12.0
#
#                        IPV_2013  DV_2014  IPV_2014  DV_2015  IPV_2015  \
# Иркутская область          34.0     50.0      43.0       52      40.0
# Рязанская область           3.0      8.0       7.0        5       5.0
# Курская область            14.0     14.0      13.0       10       8.0
# Республика Бурятия         19.0     28.0      25.0       30      26.0
# Ростовская область         27.0     26.0      20.0       38      32.0
# ...                         ...      ...       ...      ...       ...
# Республика Карелия          4.0     16.0      14.0       11      10.0
# город Санкт-Петербург      11.0     18.0      18.0       19      19.0
# Саратовская область        32.0     44.0      40.0       29      26.0
# Кировская область          12.0     30.0      28.0       22      20.0
# Республика Мордовия        10.0      7.0       6.0        7       6.0
#
#                        DV_2016  IPV_2016
# Иркутская область           43      35.0
# Рязанская область            5       5.0
# Курская область             10       8.0
# Республика Бурятия          29      23.0
# Ростовская область          25      24.0
# ...                        ...       ...
# Республика Карелия           6       6.0
# город Санкт-Петербург       19      17.0
# Саратовская область         22      19.0
# Кировская область           16      13.0
# Республика Мордовия          7       5.0
#
# [84 rows x 12 columns]
#                        DV_2011  IPV_2011  DV_2012  IPV_2012  DV_2013  \
# Иркутская область         27.0      21.0     31.0      25.0     40.0
# Рязанская область          6.0       4.0      6.0       6.0      4.0
# Курская область           17.0      14.0     10.0       8.0     17.0
# Республика Бурятия        32.0      26.0     34.0      27.0     25.0
# Ростовская область        21.0      17.0     16.0      15.0     31.0
# ...                        ...       ...      ...       ...      ...
# Республика Карелия        10.0       9.0      7.0       6.0      5.0
# город Санкт-Петербург     13.0      13.0     13.0      12.0     14.0
# Саратовская область       25.0      24.0     38.0      35.0     35.0
# Кировская область          8.0       6.0     20.0      17.0     16.0
# Республика Мордовия        5.0       5.0      7.0       7.0     12.0
#
#                        IPV_2013  DV_2014  IPV_2014  DV_2015  IPV_2015  \
# Иркутская область          34.0     50.0      43.0       52      40.0
# Рязанская область           3.0      8.0       7.0        5       5.0
# Курская область            14.0     14.0      13.0       10       8.0
# Республика Бурятия         19.0     28.0      25.0       30      26.0
# Ростовская область         27.0     26.0      20.0       38      32.0
# ...                         ...      ...       ...      ...       ...
# Республика Карелия          4.0     16.0      14.0       11      10.0
# город Санкт-Петербург      11.0     18.0      18.0       19      19.0
# Саратовская область        32.0     44.0      40.0       29      26.0
# Кировская область          12.0     30.0      28.0       22      20.0
# Республика Мордовия        10.0      7.0       6.0        7       6.0
#
#                        DV_2016  IPV_2016  DV_2017  IPV_2017
# Иркутская область           43      35.0     46.0      34.0
# Рязанская область            5       5.0      5.0       5.0
# Курская область             10       8.0      5.0       3.0
# Республика Бурятия          29      23.0     33.0      32.0
# Ростовская область          25      24.0     19.0      16.0
# ...                        ...       ...      ...       ...
# Республика Карелия           6       6.0      9.0       9.0
# город Санкт-Петербург       19      17.0     29.0      28.0
# Саратовская область         22      19.0     19.0      19.0
# Кировская область           16      13.0     16.0      16.0
# Республика Мордовия          7       5.0      2.0       1.0
#
# [84 rows x 14 columns]
#                        DV_2011  IPV_2011  DV_2012  IPV_2012  DV_2013  \
# Иркутская область         27.0      21.0     31.0      25.0     40.0
# Рязанская область          6.0       4.0      6.0       6.0      4.0
# Курская область           17.0      14.0     10.0       8.0     17.0
# Республика Бурятия        32.0      26.0     34.0      27.0     25.0
# Ростовская область        21.0      17.0     16.0      15.0     31.0
# ...                        ...       ...      ...       ...      ...
# Республика Карелия        10.0       9.0      7.0       6.0      5.0
# город Санкт-Петербург     13.0      13.0     13.0      12.0     14.0
# Саратовская область       25.0      24.0     38.0      35.0     35.0
# Кировская область          8.0       6.0     20.0      17.0     16.0
# Республика Мордовия        5.0       5.0      7.0       7.0     12.0
#
#                        IPV_2013  DV_2014  IPV_2014  DV_2015  IPV_2015  \
# Иркутская область          34.0     50.0      43.0       52      40.0
# Рязанская область           3.0      8.0       7.0        5       5.0
# Курская область            14.0     14.0      13.0       10       8.0
# Республика Бурятия         19.0     28.0      25.0       30      26.0
# Ростовская область         27.0     26.0      20.0       38      32.0
# ...                         ...      ...       ...      ...       ...
# Республика Карелия          4.0     16.0      14.0       11      10.0
# город Санкт-Петербург      11.0     18.0      18.0       19      19.0
# Саратовская область        32.0     44.0      40.0       29      26.0
# Кировская область          12.0     30.0      28.0       22      20.0
# Республика Мордовия        10.0      7.0       6.0        7       6.0
#
#                        DV_2016  IPV_2016  DV_2017  IPV_2017  DV_2019  IPV_2019
# Иркутская область           43      35.0     46.0      34.0     30.0      24.0
# Рязанская область            5       5.0      5.0       5.0      9.0       2.0
# Курская область             10       8.0      5.0       3.0      6.0       6.0
# Республика Бурятия          29      23.0     33.0      32.0     21.0      17.0
# Ростовская область          25      24.0     19.0      16.0      8.0       8.0
# ...                        ...       ...      ...       ...      ...       ...
# Республика Карелия           6       6.0      9.0       9.0      6.0       6.0
# город Санкт-Петербург       19      17.0     29.0      28.0      9.0       8.0
# Саратовская область         22      19.0     19.0      19.0     20.0      15.0
# Кировская область           16      13.0     16.0      16.0     21.0      18.0
# Республика Мордовия          7       5.0      2.0       1.0      5.0       5.0
#
# [84 rows x 16 columns]

# %% [markdown]
# #### Шаг 5. Добавляем общее число дел

# %%
years = list(range(2011, 2020))
n_cases = []
for year in years:
    if year == 2018:
        continue
    merged = pd.read_csv(f'Данные_за_все_года/{year}_merged.csv', index_col=0)
    n_cases.append([year, len(merged)])
n_cases
# Out:
# [[2011, 8914],
#  [2012, 8757],
#  [2013, 9323],
#  [2014, 10652],
#  [2015, 10036],
#  [2016, 9835],
#  [2017, 9262],
#  [2019, 6462]]

# %%
pd.DataFrame(n_cases, columns=['year', 'Количество дел']).to_excel("Количество дел.xlsx")

# %% [markdown]
# #### Шаг 6. Добавляем инфу о 2018 годе

# %%
data_2018 = pd.read_excel('Только_женские_тексты_с_разметкой_предобр_без_98.xlsx', index_col=0)
data_2018['IPV'] = data_2018['IPV'].replace({2: 0})
data_2018.head()
# Out:
#                                                                                text  \
# ID
# 82060183bdf7472e85540c4370d3693c  Дело № 1-318/2018\nПоступило в суд 04.12.2018\...
# 377054bb5594776bb30ff64c6ebcffb8  Уг.д. № 1-45/2018 (11701330019047312)\nП Р И Г...
# 6df614cdfd7d029cde776d52ed7932d2  UNKNOWN {\n\tTEXT-ALIGN: justify\n}\n\n\n\n   ...
# 50593bc68988c7aae8f9f2f2bf243f8a  Дело № 1-19/2018\nПриговор \nИменем Российской...
# 54e009a196b97005a1b4d828670345e7  Дело №1-1-33\2018\nПРИГОВОР\nИменем Российской...
#
#                                   DV  IPV  \
# ID
# 82060183bdf7472e85540c4370d3693c   1  1.0
# 377054bb5594776bb30ff64c6ebcffb8   1  1.0
# 6df614cdfd7d029cde776d52ed7932d2   1  1.0
# 50593bc68988c7aae8f9f2f2bf243f8a   1  1.0
# 54e009a196b97005a1b4d828670345e7   1  1.0
#
#                                                                           text_prep
# ID
# 82060183bdf7472e85540c4370d3693c  дело поступать российский федерация декабрь ку...
# 377054bb5594776bb30ff64c6ebcffb8  российский федерация город яранск кировский об...
# 6df614cdfd7d029cde776d52ed7932d2  дело российский федерация урюпинск август судь...
# 50593bc68988c7aae8f9f2f2bf243f8a  дело приговор российский федерация тихвин янва...
# 54e009a196b97005a1b4d828670345e7  дело приговор российский федерация март город ...

# %%
display(data_2018['DV'].value_counts(normalize=True), data_2018['IPV'].value_counts(normalize=True))
# Out:
# 1    0.691176
# 0    0.308824
# Name: DV, dtype: float64
# 1.0    0.80213
# 0.0    0.19787
# Name: IPV, dtype: float64

# %%
len(data_2018)
# Out:
# 1632

# %%
data_reg_2018 = pd.read_excel('2018_women_cases_MERGED.xlsx', index_col=0).drop_duplicates('ID').set_index("ID")
data_reg_2018
# Out:
#                                        Номер дела (материала)  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300             01-0796/2018
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6             01-0520/2018
# a3bd299f-e55e-474d-84f0-7cdcc7f53869             01-0511/2018
# e26be2b3-cd2d-4237-a202-6ccc720ad557             01-0472/2018
# 743790b9-307e-49e4-bb69-1a4b4e3fd872             01-0471/2018
# ...                                                       ...
# 552c2eac9cc2672729ab438742c61bf3                   1-264/2018
# 6f42bca4eb76fcd6acdfcf216edb1294                   1-598/2018
# ce8b099236e8ae205ad95bc76e9bda54      1-20/2018 (1-364/2017;)
# 6079cf39d935ad1864daf52eab11b90f                   1-2-7/2018
# b4c70b7301774b3952a9ff8a1c2b93bd                    1-44/2018
#
#                                                                                 Стороны  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300        Подсудимый: Васильев Н.Б.  (Ст. 105, Ч. 1;)
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6      Подсудимый: Родимушкин Н.В.  (Ст. 105, Ч. 1;)
# a3bd299f-e55e-474d-84f0-7cdcc7f53869         Подсудимый: Семенов Л.В.  (Ст. 105, Ч. 1;)
# e26be2b3-cd2d-4237-a202-6ccc720ad557        Подсудимый: Остриков А.В.  (Ст. 105, Ч. 1;)
# 743790b9-307e-49e4-bb69-1a4b4e3fd872  Подсудимый: Никишин П.О.  (Ст. 105, Ч. 2, пп. ...
# ...                                                                                 ...
# 552c2eac9cc2672729ab438742c61bf3                                                    NaN
# 6f42bca4eb76fcd6acdfcf216edb1294                                                    NaN
# ce8b099236e8ae205ad95bc76e9bda54                                                    NaN
# 6079cf39d935ad1864daf52eab11b90f                                                    NaN
# b4c70b7301774b3952a9ff8a1c2b93bd                                                    NaN
#
#                                                         Результат  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300  Вступило в силу, 23.10.2018
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6         Изменено, 06.02.2019
# a3bd299f-e55e-474d-84f0-7cdcc7f53869  Вступило в силу, 21.12.2018
# e26be2b3-cd2d-4237-a202-6ccc720ad557  Вступило в силу, 17.07.2018
# 743790b9-307e-49e4-bb69-1a4b4e3fd872  Вступило в силу, 25.10.2018
# ...                                                           ...
# 552c2eac9cc2672729ab438742c61bf3                 Вынесен ПРИГОВОР
# 6f42bca4eb76fcd6acdfcf216edb1294                 Вынесен ПРИГОВОР
# ce8b099236e8ae205ad95bc76e9bda54                 Вынесен ПРИГОВОР
# 6079cf39d935ad1864daf52eab11b90f                 Вынесен ПРИГОВОР
# b4c70b7301774b3952a9ff8a1c2b93bd                 Вынесен ПРИГОВОР
#
#                                                  Судья  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300  Борисенкова Н.В.
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6      Филатов А.Ю.
# a3bd299f-e55e-474d-84f0-7cdcc7f53869        Чечко Л.Н.
# e26be2b3-cd2d-4237-a202-6ccc720ad557  Борисенкова Н.В.
# 743790b9-307e-49e4-bb69-1a4b4e3fd872     Кузнецов В.С.
# ...                                                ...
# 552c2eac9cc2672729ab438742c61bf3                   NaN
# 6f42bca4eb76fcd6acdfcf216edb1294                   NaN
# ce8b099236e8ae205ad95bc76e9bda54                   NaN
# 6079cf39d935ad1864daf52eab11b90f                   NaN
# b4c70b7301774b3952a9ff8a1c2b93bd                   NaN
#
#                                                                            Статья УК РФ  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300                                      Ст. 105, Ч. 1
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6                                      Ст. 105, Ч. 1
# a3bd299f-e55e-474d-84f0-7cdcc7f53869                                      Ст. 105, Ч. 1
# e26be2b3-cd2d-4237-a202-6ccc720ad557                                      Ст. 105, Ч. 1
# 743790b9-307e-49e4-bb69-1a4b4e3fd872                                      Ст. 105, Ч. 2
# ...                                                                                 ...
# 552c2eac9cc2672729ab438742c61bf3      Статья 166 Часть 1; Статья 158 Часть 2 п.в; Ст...
# 6f42bca4eb76fcd6acdfcf216edb1294      Статья 161 Часть 1; Статья 158 Часть 2 п.в; Ст...
# ce8b099236e8ae205ad95bc76e9bda54      Статья 115 Часть 2 п.в; Статья 115 Часть 2 п.в...
# 6079cf39d935ad1864daf52eab11b90f      Статья 127 Часть 1; Статья 127 Часть 1; Статья...
# b4c70b7301774b3952a9ff8a1c2b93bd      Статья 158 Часть 1; Статья 158 Часть 1; Статья...
#
#                                                                                     URL  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300  https://mos-gorsud.ru/rs/nagatinskij/services/...
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6  https://mos-gorsud.ru/rs/nagatinskij/services/...
# a3bd299f-e55e-474d-84f0-7cdcc7f53869  https://mos-gorsud.ru/rs/zyuzinskij/services/c...
# e26be2b3-cd2d-4237-a202-6ccc720ad557  https://mos-gorsud.ru/rs/nagatinskij/services/...
# 743790b9-307e-49e4-bb69-1a4b4e3fd872  https://mos-gorsud.ru/rs/lyublinskij/services/...
# ...                                                                                 ...
# 552c2eac9cc2672729ab438742c61bf3                                                    NaN
# 6f42bca4eb76fcd6acdfcf216edb1294                                                    NaN
# ce8b099236e8ae205ad95bc76e9bda54                                                    NaN
# 6079cf39d935ad1864daf52eab11b90f                                                    NaN
# b4c70b7301774b3952a9ff8a1c2b93bd                                                    NaN
#
#                                                                             URL_verdict  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300  https://mos-gorsud.ru/rs/nagatinskij/cases/doc...
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6  https://mos-gorsud.ru/rs/nagatinskij/cases/doc...
# a3bd299f-e55e-474d-84f0-7cdcc7f53869  https://mos-gorsud.ru/rs/zyuzinskij/cases/docs...
# e26be2b3-cd2d-4237-a202-6ccc720ad557  https://mos-gorsud.ru/rs/nagatinskij/cases/doc...
# 743790b9-307e-49e4-bb69-1a4b4e3fd872  https://mos-gorsud.ru/rs/lyublinskij/cases/doc...
# ...                                                                                 ...
# 552c2eac9cc2672729ab438742c61bf3                                                    NaN
# 6f42bca4eb76fcd6acdfcf216edb1294                                                    NaN
# ce8b099236e8ae205ad95bc76e9bda54                                                    NaN
# 6079cf39d935ad1864daf52eab11b90f                                                    NaN
# b4c70b7301774b3952a9ff8a1c2b93bd                                                    NaN
#
#                                                                                    text  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300  1-796/2018 ПРИГОВОР Именем Российской Федераци...
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6  Уголовное дело № 1-520/2018 П Р И Г О В О Р Им...
# a3bd299f-e55e-474d-84f0-7cdcc7f53869  \t\t\t\t\t\t\t                                ...
# e26be2b3-cd2d-4237-a202-6ccc720ad557  1-472/2018 ПРИГОВОР Именем Российской Федераци...
# 743790b9-307e-49e4-bb69-1a4b4e3fd872  Дело № 1-471/2018                 П Р И Г О В ...
# ...                                                                                 ...
# 552c2eac9cc2672729ab438742c61bf3      Дело № 1-264/18П Р И Г О В О Р Именем Российск...
# 6f42bca4eb76fcd6acdfcf216edb1294      Дело № (сл. №)\n\nП Р И Г О В О Р \nИ М Е Н Е ...
# ce8b099236e8ae205ad95bc76e9bda54      UNKNOWN {\r\n\tTEXT-ALIGN: justify\r\n}\r\n\n\...
# 6079cf39d935ad1864daf52eab11b90f      Дело № 1-2-7/2018\nП Р И Г О В О Р\nИМЕНЕМ РОС...
# b4c70b7301774b3952a9ff8a1c2b93bd      Дело № 1-44/2018 \nП Р И Г О В О Р\nИменем Рос...
#
#                                             Источник             Субъект РФ  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300       Мосгорсуд                 Москва
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6       Мосгорсуд                 Москва
# a3bd299f-e55e-474d-84f0-7cdcc7f53869       Мосгорсуд                 Москва
# e26be2b3-cd2d-4237-a202-6ccc720ad557       Мосгорсуд                 Москва
# 743790b9-307e-49e4-bb69-1a4b4e3fd872       Мосгорсуд                 Москва
# ...                                              ...                    ...
# 552c2eac9cc2672729ab438742c61bf3      ГАС Правосудие         Алтайский край
# 6f42bca4eb76fcd6acdfcf216edb1294      ГАС Правосудие     Московская область
# ce8b099236e8ae205ad95bc76e9bda54      ГАС Правосудие         Омская область
# 6079cf39d935ad1864daf52eab11b90f      ГАС Правосудие      Калужская область
# b4c70b7301774b3952a9ff8a1c2b93bd      ГАС Правосудие  Удмуртская Республика
#
#                                      Тип документа  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300      Приговор
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6      Приговор
# a3bd299f-e55e-474d-84f0-7cdcc7f53869      Приговор
# e26be2b3-cd2d-4237-a202-6ccc720ad557      Приговор
# 743790b9-307e-49e4-bb69-1a4b4e3fd872      Приговор
# ...                                            ...
# 552c2eac9cc2672729ab438742c61bf3          Приговор
# 6f42bca4eb76fcd6acdfcf216edb1294          Приговор
# ce8b099236e8ae205ad95bc76e9bda54          Приговор
# 6079cf39d935ad1864daf52eab11b90f          Приговор
# b4c70b7301774b3952a9ff8a1c2b93bd          Приговор
#
#                                                                                     ФИО  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300                                      Васильев Н.Б.
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6                                    Родимушкин Н.В.
# a3bd299f-e55e-474d-84f0-7cdcc7f53869                                       Семенов Л.В.
# e26be2b3-cd2d-4237-a202-6ccc720ad557                                      Остриков А.В.
# 743790b9-307e-49e4-bb69-1a4b4e3fd872                                       Никишин П.О.
# ...                                                                                 ...
# 552c2eac9cc2672729ab438742c61bf3                           Сурсков Андрей Александрович
# 6f42bca4eb76fcd6acdfcf216edb1294                                          Шарашкин Б.А.
# ce8b099236e8ae205ad95bc76e9bda54      Воякин Сергей Николаевич, Хибарин Руслан Анато...
# 6079cf39d935ad1864daf52eab11b90f                            Ситенков Дмитрий Алексеевич
# b4c70b7301774b3952a9ff8a1c2b93bd                       Мерзляков Константин Геннадьевич
#
#                                                          Наименование суда  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300              Нагатинский районный суд
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6              Нагатинский районный суд
# a3bd299f-e55e-474d-84f0-7cdcc7f53869                Зюзинский районный суд
# e26be2b3-cd2d-4237-a202-6ccc720ad557              Нагатинский районный суд
# 743790b9-307e-49e4-bb69-1a4b4e3fd872               Люблинский районный суд
# ...                                                                    ...
# 552c2eac9cc2672729ab438742c61bf3      Октябрьский районный суд г. Барнаула
# 6f42bca4eb76fcd6acdfcf216edb1294            Орехово-Зуевский городской суд
# ce8b099236e8ae205ad95bc76e9bda54        Куйбышевский районный суд г. Омска
# 6079cf39d935ad1864daf52eab11b90f                  Людиновский районный суд
# b4c70b7301774b3952a9ff8a1c2b93bd               Малопургинский районный суд
#
#                                            №  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300     NaN
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6     NaN
# a3bd299f-e55e-474d-84f0-7cdcc7f53869     NaN
# e26be2b3-cd2d-4237-a202-6ccc720ad557     NaN
# 743790b9-307e-49e4-bb69-1a4b4e3fd872     NaN
# ...                                      ...
# 552c2eac9cc2672729ab438742c61bf3      3153.0
# 6f42bca4eb76fcd6acdfcf216edb1294      3154.0
# ce8b099236e8ae205ad95bc76e9bda54      3159.0
# 6079cf39d935ad1864daf52eab11b90f      3166.0
# b4c70b7301774b3952a9ff8a1c2b93bd      3170.0
#
#                                                                               Аннотация  \
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300                                                NaN
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6                                                NaN
# a3bd299f-e55e-474d-84f0-7cdcc7f53869                                                NaN
# e26be2b3-cd2d-4237-a202-6ccc720ad557                                                NaN
# 743790b9-307e-49e4-bb69-1a4b4e3fd872                                                NaN
# ...                                                                                 ...
# 552c2eac9cc2672729ab438742c61bf3      ... я 166 Часть 1; Статья 158 Часть 2 п.в; Ста...
# 6f42bca4eb76fcd6acdfcf216edb1294      ... 8 Часть 2 п.в; Статья 158 Часть 3 п.а; Ста...
# ce8b099236e8ae205ad95bc76e9bda54      ... сть 2 п.в; Статья 127 Часть 2 п.п.г,ж; Ста...
# 6079cf39d935ad1864daf52eab11b90f                                               Приговор
# b4c70b7301774b3952a9ff8a1c2b93bd                                               Приговор
#
#                                      Дата поступления Дата решения
# ID
# c21b02c4-9fcd-4375-b0f6-2de4aa87b300              NaN          NaN
# 2f8ccdca-bf56-4dda-a8ab-13791848f3e6              NaN          NaN
# a3bd299f-e55e-474d-84f0-7cdcc7f53869              NaN          NaN
# e26be2b3-cd2d-4237-a202-6ccc720ad557              NaN          NaN
# 743790b9-307e-49e4-bb69-1a4b4e3fd872              NaN          NaN
# ...                                               ...          ...
# 552c2eac9cc2672729ab438742c61bf3           08.05.2018   25.06.2018
# 6f42bca4eb76fcd6acdfcf216edb1294           30.08.2018   08.11.2018
# ce8b099236e8ae205ad95bc76e9bda54           14.09.2017   09.01.2018
# 6079cf39d935ad1864daf52eab11b90f           11.05.2018   25.06.2018
# b4c70b7301774b3952a9ff8a1c2b93bd           08.02.2018   19.04.2018
#
# [1825 rows x 17 columns]

# %%
data_2018['IPV'].value_counts()
# Out:
# 1.0    904
# 0.0    223
# Name: IPV, dtype: int64

# %%
data_2018['region'] = data_reg_2018['Субъект РФ'].replace({'Москва': 'город Москва', 'Город Москва': 'город Москва'})
data_2018.head()
# Out:
#                                                                                text  \
# ID
# 82060183bdf7472e85540c4370d3693c  Дело № 1-318/2018\nПоступило в суд 04.12.2018\...
# 377054bb5594776bb30ff64c6ebcffb8  Уг.д. № 1-45/2018 (11701330019047312)\nП Р И Г...
# 6df614cdfd7d029cde776d52ed7932d2  UNKNOWN {\n\tTEXT-ALIGN: justify\n}\n\n\n\n   ...
# 50593bc68988c7aae8f9f2f2bf243f8a  Дело № 1-19/2018\nПриговор \nИменем Российской...
# 54e009a196b97005a1b4d828670345e7  Дело №1-1-33\2018\nПРИГОВОР\nИменем Российской...
#
#                                   DV  IPV  \
# ID
# 82060183bdf7472e85540c4370d3693c   1  1.0
# 377054bb5594776bb30ff64c6ebcffb8   1  1.0
# 6df614cdfd7d029cde776d52ed7932d2   1  1.0
# 50593bc68988c7aae8f9f2f2bf243f8a   1  1.0
# 54e009a196b97005a1b4d828670345e7   1  1.0
#
#                                                                           text_prep  \
# ID
# 82060183bdf7472e85540c4370d3693c  дело поступать российский федерация декабрь ку...
# 377054bb5594776bb30ff64c6ebcffb8  российский федерация город яранск кировский об...
# 6df614cdfd7d029cde776d52ed7932d2  дело российский федерация урюпинск август судь...
# 50593bc68988c7aae8f9f2f2bf243f8a  дело приговор российский федерация тихвин янва...
# 54e009a196b97005a1b4d828670345e7  дело приговор российский федерация март город ...
#
#                                                  region
# ID
# 82060183bdf7472e85540c4370d3693c  Новосибирская область
# 377054bb5594776bb30ff64c6ebcffb8      Кировская область
# 6df614cdfd7d029cde776d52ed7932d2  Волгоградская область
# 50593bc68988c7aae8f9f2f2bf243f8a  Ленинградская область
# 54e009a196b97005a1b4d828670345e7      Орловская область

# %%
regions_2018 = pd.pivot_table(data_2018, index='region', values=['DV','IPV'], aggfunc=sum)
regions_2018.head()
# Out:
#                        DV   IPV
# region
# Алтайский край         32  25.0
# Амурская область       10   7.0
# Архангельская область  14   8.0
# Астраханская область    7   5.0
# Белгородская область    5   4.0

# %%
regions_dynamics[['DV_2018', 'IPV_2018']] = regions_2018[['DV', 'IPV']]
regions_dynamics.tail()
# Out:
#                        DV_2011  IPV_2011  DV_2012  IPV_2012  DV_2013  \
# Республика Карелия        10.0       9.0      7.0       6.0      5.0
# город Санкт-Петербург     13.0      13.0     13.0      12.0     14.0
# Саратовская область       25.0      24.0     38.0      35.0     35.0
# Кировская область          8.0       6.0     20.0      17.0     16.0
# Республика Мордовия        5.0       5.0      7.0       7.0     12.0
#
#                        IPV_2013  DV_2014  IPV_2014  DV_2015  IPV_2015  \
# Республика Карелия          4.0     16.0      14.0       11      10.0
# город Санкт-Петербург      11.0     18.0      18.0       19      19.0
# Саратовская область        32.0     44.0      40.0       29      26.0
# Кировская область          12.0     30.0      28.0       22      20.0
# Республика Мордовия        10.0      7.0       6.0        7       6.0
#
#                        DV_2016  IPV_2016  DV_2017  IPV_2017  DV_2019  \
# Республика Карелия           6       6.0      9.0       9.0      6.0
# город Санкт-Петербург       19      17.0     29.0      28.0      9.0
# Саратовская область         22      19.0     19.0      19.0     20.0
# Кировская область           16      13.0     16.0      16.0     21.0
# Республика Мордовия          7       5.0      2.0       1.0      5.0
#
#                        IPV_2019  DV_2018  IPV_2018
# Республика Карелия          6.0     11.0      10.0
# город Санкт-Петербург       8.0     11.0       8.0
# Саратовская область        15.0      9.0       7.0
# Кировская область          18.0     13.0       9.0
# Республика Мордовия         5.0      2.0       2.0

# %%
regions_dynamics = regions_dynamics[[f'DV_{year}' for year in range(2011, 2020)] + [f'IPV_{year}' for year in range(2011, 2020)]]
regions_dynamics.head()
# Out:
#                     DV_2011  DV_2012  DV_2013  DV_2014  DV_2015  DV_2016  \
# Иркутская область      27.0     31.0     40.0     50.0       52       43
# Рязанская область       6.0      6.0      4.0      8.0        5        5
# Курская область        17.0     10.0     17.0     14.0       10       10
# Республика Бурятия     32.0     34.0     25.0     28.0       30       29
# Ростовская область     21.0     16.0     31.0     26.0       38       25
#
#                     DV_2017  DV_2018  DV_2019  IPV_2011  IPV_2012  IPV_2013  \
# Иркутская область      46.0     30.0     30.0      21.0      25.0      34.0
# Рязанская область       5.0      5.0      9.0       4.0       6.0       3.0
# Курская область         5.0      8.0      6.0      14.0       8.0      14.0
# Республика Бурятия     33.0     30.0     21.0      26.0      27.0      19.0
# Ростовская область     19.0     18.0      8.0      17.0      15.0      27.0
#
#                     IPV_2014  IPV_2015  IPV_2016  IPV_2017  IPV_2018  IPV_2019
# Иркутская область       43.0      40.0      35.0      34.0      21.0      24.0
# Рязанская область        7.0       5.0       5.0       5.0       4.0       2.0
# Курская область         13.0       8.0       8.0       3.0       3.0       6.0
# Республика Бурятия      25.0      26.0      23.0      32.0      24.0      17.0
# Ростовская область      20.0      32.0      24.0      16.0      16.0       8.0

# %%
regions_dynamics.loc['Всего'] = regions_dynamics.sum()
regions_dynamics['DV_Всего'] = regions_dynamics[[col for col in regions_dynamics.columns if 'DV' in col]].sum(axis=1)
regions_dynamics['IPV_Всего'] = regions_dynamics[[col for col in regions_dynamics.columns if 'IPV' in col]].sum(axis=1)
regions_dynamics.tail()
# Out:
#                        DV_2011  DV_2012  DV_2013  DV_2014  DV_2015  DV_2016  \
# город Санкт-Петербург     13.0     13.0     14.0     18.0     19.0     19.0
# Саратовская область       25.0     38.0     35.0     44.0     29.0     22.0
# Кировская область          8.0     20.0     16.0     30.0     22.0     16.0
# Республика Мордовия        5.0      7.0     12.0      7.0      7.0      7.0
# Всего                   1578.0   1573.0   1654.0   1915.0   1742.0   1734.0
#
#                        DV_2017  DV_2018  DV_2019  IPV_2011  IPV_2012  \
# город Санкт-Петербург     29.0     11.0      9.0      13.0      12.0
# Саратовская область       19.0      9.0     20.0      24.0      35.0
# Кировская область         16.0     13.0     21.0       6.0      17.0
# Республика Мордовия        2.0      2.0      5.0       5.0       7.0
# Всего                   1581.0   1127.0   1108.0    1356.0    1345.0
#
#                        IPV_2013  IPV_2014  IPV_2015  IPV_2016  IPV_2017  \
# город Санкт-Петербург      11.0      18.0      19.0      17.0      28.0
# Саратовская область        32.0      40.0      26.0      19.0      19.0
# Кировская область          12.0      28.0      20.0      13.0      16.0
# Республика Мордовия        10.0       6.0       6.0       5.0       1.0
# Всего                    1416.0    1652.0    1504.0    1487.0    1364.0
#
#                        IPV_2018  IPV_2019  DV_Всего  IPV_Всего
# город Санкт-Петербург       8.0       8.0     145.0      134.0
# Саратовская область         7.0      15.0     241.0      217.0
# Кировская область           9.0      18.0     162.0      139.0
# Республика Мордовия         2.0       5.0      54.0       47.0
# Всего                     904.0     965.0   14012.0    11993.0

# %%
len(regions_dynamics)
# Out:
# 85

# %%
# без поправки на точность
regions_dynamics.to_excel('Динамика по регионам (без поправки).xlsx')

# %%
regions_dynamics.drop('Всего', inplace = True)
regions_dynamics.drop(['DV_Всего', 'IPV_Всего'], axis=1, inplace=True)

for col in regions_dynamics.columns:
    if '2018' in col:
        continue
    if 'DV' in col:
        regions_dynamics[col] = regions_dynamics[col]*prec_dv_model
    elif 'IPV' in col:
        regions_dynamics[col] = regions_dynamics[col]*prec_dv_model*prec_ipv_model
        
regions_dynamics.loc['Всего'] = regions_dynamics.sum()
regions_dynamics['DV_Всего'] = regions_dynamics[[col for col in regions_dynamics.columns if 'DV' in col]].sum(axis=1)
regions_dynamics['IPV_Всего'] = regions_dynamics[[col for col in regions_dynamics.columns if 'IPV' in col]].sum(axis=1)
regions_dynamics.tail()
# Out:
#                        DV_2011  DV_2012  DV_2013  DV_2014  DV_2015  DV_2016  \
# город Санкт-Петербург    11.18    11.18    12.04    15.48    16.34    16.34
# Саратовская область      21.50    32.68    30.10    37.84    24.94    18.92
# Кировская область         6.88    17.20    13.76    25.80    18.92    13.76
# Республика Мордовия       4.30     6.02    10.32     6.02     6.02     6.02
# Всего                  1357.08  1352.78  1422.44  1646.90  1498.12  1491.24
#
#                        DV_2017  DV_2018  DV_2019   IPV_2011   IPV_2012  \
# город Санкт-Петербург    24.94     11.0     7.74    10.5092     9.7008
# Саратовская область      16.34      9.0    17.20    19.4016    28.2940
# Кировская область        13.76     13.0    18.06     4.8504    13.7428
# Республика Мордовия       1.72      2.0     4.30     4.0420     5.6588
# Всего                  1359.66   1127.0   952.88  1096.1904  1087.2980
#
#                         IPV_2013   IPV_2014   IPV_2015   IPV_2016   IPV_2017  \
# город Санкт-Петербург     8.8924    14.5512    15.3596    13.7428    22.6352
# Саратовская область      25.8688    32.3360    21.0184    15.3596    15.3596
# Кировская область         9.7008    22.6352    16.1680    10.5092    12.9344
# Республика Мордовия       8.0840     4.8504     4.8504     4.0420     0.8084
# Всего                  1144.6944  1335.4768  1215.8336  1202.0908  1102.6576
#
#                        IPV_2018  IPV_2019  DV_Всего  IPV_Всего
# город Санкт-Петербург       8.0    6.4672    126.24   109.8584
# Саратовская область         7.0   12.1260    208.52   176.7640
# Кировская область           9.0   14.5512    141.14   114.0920
# Республика Мордовия         2.0    4.0420     46.72    38.3780
# Всего                     904.0  780.1060  12208.10  9868.3476

# %%
regions_dynamics.apply(round).to_excel('Динамика по регионам (с поправкой).xlsx')

# %% [markdown]
# #### Шаг 7. Ключевые слова

# %%
import pickle

with open("cvect.pkl", 'rb') as file:
    cvect = pickle.load(file)

# %%
cvect.get_feature_names()
# Out:
# ['абонентский',
#  'абонентский номер',
#  'август',
#  'автомашина',
#  'автомобиль',
#  'агрессивный',
#  'агрессия',
#  'адвокат',
#  'адвокатский',
#  'адекватно',
#  'адекватный',
#  'административный',
#  'административный ответственность',
#  'администрация',
#  'акт',
#  'акт медицинский',
#  'активно',
#  'активный',
#  'активный действие',
#  'активный сопротивление',
#  'активный способствование',
#  'активный целенаправленный',
#  'алкоголизм',
#  'алкоголь',
#  'алкоголь поскольку',
#  'алкогольный',
#  'алкогольный напиток',
#  'алкогольный опьянение',
#  'амбулаторный',
#  'амбулаторный комплексный',
#  'аморальность',
#  'аморальный',
#  'аморальный поведение',
#  'анализ',
#  'анализировать',
#  'аналогичный',
#  'анатомический',
#  'антиген',
#  'апелляционный',
#  'апелляционный жалоба',
#  'апелляционный инстанция',
#  'апелляционный порядок',
#  'апелляционный представление',
#  'апрель',
#  'арест',
#  'артерия',
#  'асфиксия',
#  'аффект',
#  'бабушка',
#  'балкон',
#  'банка',
#  'банковский',
#  'банковский карта',
#  'баня',
#  'бегать',
#  'бедро',
#  'бежать',
#  'белый',
#  'белый цвет',
#  'белье',
#  'беседа',
#  'беспорядок',
#  'бессознательный',
#  'бессознательный состояние',
#  'биологический',
#  'биологический материал',
#  'биологический смерть',
#  'биологический экспертиза',
#  'бить',
#  'близкий',
#  'близкий отношение',
#  'близкий родственник',
#  'близость',
#  'бок',
#  'боковой',
#  'боковой поверхность',
#  'болезненный',
#  'болезненный расстройство',
#  'болезненный состояние',
#  'болезнь',
#  'болеть',
#  'боль',
#  'больница',
#  'больно',
#  'больной',
#  'больший',
#  'большой',
#  'большой количество',
#  'большой палец',
#  'борозда',
#  'борьба',
#  'ботинок',
#  'бояться',
#  'брак',
#  'брак состоять',
#  'брань',
#  'брат',
#  'брать',
#  'бред',
#  'бред галлюцинация',
#  'бригада',
#  'бригада скорый',
#  'бровь',
#  'бросать',
#  'брыжейка',
#  'брызги',
#  'брюки',
#  'брюшной',
#  'брюшной полость',
#  'брюшной стенка',
#  'бсмэ',
#  'будить',
#  'бумага',
#  'бумажный',
#  'бурый',
#  'бурый цвет',
#  'бутылка',
#  'бутылка водка',
#  'бутылка пиво',
#  'бывало',
#  'бывать',
#  'бывший',
#  'бывший муж',
#  'быстро',
#  'быстрый',
#  'быт',
#  'бытовой',
#  'бытовой назначение',
#  'бытовой почва',
#  'бюджет',
#  'бюджет процессуальный',
#  'бюро',
#  'бюро смэ',
#  'бюстгальтер',
#  'ванна',
#  'ванная',
#  'ванная комната',
#  'ванный',
#  'ванный комната',
#  'вблизи',
#  'ввиду',
#  'вдвоем',
#  'вдоль',
#  'ведение',
#  'ведро',
#  'ведущий',
#  'век',
#  'век левый',
#  'век правый',
#  'вена',
#  'веранда',
#  'веревка',
#  'вернуть',
#  'вернуться',
#  'вернуться дом',
#  'вернуться домой',
#  'вернуться квартира',
#  'вернуться комната',
#  'вернуться обратно',
#  'верный',
#  'вероятно',
#  'вероятность',
#  'вероятный',
#  'версия',
#  'вертикальный',
#  'верхний',
#  'верхний век',
#  'верхний губа',
#  'верхний доля',
#  'верхний конечность',
#  'верхний нижний',
#  'верхний одежда',
#  'верхний средний',
#  'верхний треть',
#  'верхний часть',
#  'верховный',
#  'верховный республика',
#  'весна',
#  'вести',
#  'вести агрессивный',
#  'вести адекватно',
#  'вести неадекватно',
#  'вести спокойно',
#  'вечер',
#  'вечер позвонить',
#  'вечер приходить',
#  'вечерний',
#  'вещественный',
#  'вещественный доказательство',
#  'вещество',
#  'вещество бурый',
#  'вещество головной',
#  'вещество красный',
#  'вещь',
#  'взаимно',
#  'взаимный',
#  'взаимоотношение',
#  'взаимоотношения',
#  'взаиморасположение',
#  'взволновать',
#  'взыскание',
#  'взыскивать',
#  'взять',
#  'взять кухонный',
#  'взять нож',
#  'взять правый',
#  'взять рука',
#  'взять стол',
#  'вид',
#  'вид заключение',
#  'вид исправительный',
#  'вид колоть',
#  'вид кровоподтек',
#  'вид лишение',
#  'вид мера',
#  'вид месяц',
#  'вид множественный',
#  'вид наступление',
#  'вид ограничение',
#  'вид причинение',
#  'вид размер',
#  'вид реальный',
#  'вид смерть',
#  'вид содержание',
#  'вид ссадина',
#  'видеозапись',
#  'видеть',
#  'видеть лицо',
#  'видеть мать',
#  'видеть синяк',
#  'видеться',
#  'видимо',
#  'видимый',
#  'видимый телесный',
#  'видно',
#  'видный',
#  'вина',
#  'вина вино',
#  'вина инкриминировать',
#  'вина предъявлять',
#  'вина признавать',
#  'вина раскаяние',
#  'вина совершение',
#  'вино',
#  'вино инкриминировать',
#  'вино подтверждаться',
#  'вино предъявлять',
#  'вино совершение',
#  'вино совершенный',
#  'виноватый',
#  'виновность',
#  'виновность подтверждаться',
#  'виновность совершение',
#  'виновный',
#  'виновный обстоятельство',
#  'виновный признавать',
#  'виновный совершение',
#  'виновный число',
#  'висеть',
#  'височный',
#  'височный доля',
#  'височный область',
#  'включать',
#  'включительно',
#  'влечь',
#  'влечь кратковременный',
#  'влияние',
#  'влияние исправление',
#  'влияние назначать',
#  'влияние поведение',
#  'влиять',
#  'вменяемость',
#  'вменяемый',
#  'вменять',
#  'вместе',
#  'вместе выпивать',
#  'вместе мать',
#  'вместе пойти',
#  'вместе проживать',
#  'вместе распивать',
#  'вместе становиться',
#  'вместе употреблять',
#  'вмешиваться',
#  'внезапно',
#  'внезапно возникать',
#  'внешний',
#  'внешний вид',
#  'внимание',
#  'внимание обстоятельство',
#  'внимание характер',
#  'внимательность',
#  'внимательность предусмотрительность',
#  'вновь',
#  'вносить',
#  'внук',
#  'внутренний',
#  'внутренний орган',
#  'внутренний поверхность',
#  'внутри',
#  'внутрь',
#  'внучка',
#  'вода',
#  'водитель',
#  'водка',
#  'военнообязанный',
#  'возбуждать',
#  'возбуждение',
#  'возбуждение уголовный',
#  'возбужденный',
#  'возвращать',
#  'возвращаться',
#  'возвращаться домой',
#  'возвращение',
#  'воздействие',
#  'воздействие колющий',
#  'воздействие область',
#  'воздействие острый',
#  'воздействие плоский',
#  'воздействие предмет',
#  'воздействие твердый',
#  'воздействие тупой',
#  'воздух',
#  'возлагать',
#  'возле',
#  'возле дом',
#  'возмещать',
#  'возмещение',
#  'возмещение материальный',
#  'возможно',
#  'возможность',
#  'возможность наступление',
#  'возможность неизбежность',
#  'возможность образование',
#  'возможность причинение',
#  'возможный',
#  'возможный назначать',
#  'возможный условие',
#  'вознаграждение',
#  'возникать',
#  'возникать конфликт',
#  'возникать личный',
#  'возникать неприязненный',
#  'возникать почва',
#  'возникать преступный',
#  'возникать результат',
#  'возникать словесный',
#  'возникать ссора',
#  'возникать умысел',
#  'возникновение',
#  'возражать',
#  'возражение',
#  'возраст',
#  'возраст состояние',
#  'волнение',
#  'волос',
#  'волосистый',
#  'волосистый часть',
#  'воля',
#  'вообще',
#  'вооружаться',
#  'вопреки',
#  'вопрос',
#  'вопрос вещественный',
#  'вопрос отвечать',
#  'ворота',
#  'воспитание',
#  'воспитывать',
#  'воспользоваться',
#  'воспользоваться конституция',
#  'воспользоваться право',
#  'воспринимать',
#  'воспринимать обстоятельство',
#  'восприятие',
#  'воспроизводить',
#  'восстановление',
#  'восстановление социальный',
#  'впервые',
#  'вперед',
#  'впоследствии',
#  'вправе',
#  'вправе ходатайствовать',
#  'впускать',
#  'врач',
#  'врач нарколог',
#  'врач психиатр',
#  'врач скорый',
#  'вред',
#  'вред здоровье',
#  'вред причинять',
#  'вред размер',
#  'временный',
#  'временный болезненный',
#  'временный психический',
#  'вроде',
#  'вручение',
#  'вручение копия',
#  'вскоре',
#  'вскрытие',
#  'вслед',
#  'вследствие',
#  'вспомнить',
#  'вспыльчивый',
#  'вставать',
#  'встреча',
#  'встречать',
#  'встречаться',
#  'вступать',
#  'вступление',
#  'вступление приговор',
#  'втроем',
#  'вход',
#  'вход дом',
#  'вход квартира',
#  'вход комната',
#  'входить',
#  'входить квартира',
#  'входной',
#  'входной дверь',
#  'выбегать',
#  'выбивать',
#  'выбрасывать',
#  'вывод',
#  'вывод вино',
#  'вывод виновность',
#  'вывод доказанность',
#  'вывод заключение',
#  'вывод медицинский',
#  'вывод эксперт',
#  'выводить',
#  'выглядеть',
#  'выгонять',
#  'выгонять дом',
#  'выдавать',
#  'выделять',
#  'выдерживать',
#  'выезд',
#  'выезжать',
#  'выезжать место',
#  'выезжать предел',
#  'выемка',
#  'вызов',
#  'вызов скорый',
#  'вызывать',
#  'вызывать бригада',
#  'вызывать полиция',
#  'вызывать скорый',
#  'вызывать сомнение',
#  'вызывать сотрудник',
#  'вызывать такси',
#  'вызывать употребление',
#  'выкидывать',
#  'выключать',
#  'вынесение',
#  'вынести',
#  'выпивать',
#  'выпивать бутылка',
#  'выпивать водка',
#  'выпивать рюмка',
#  'выпивать спиртное',
#  'выплата',
#  'выплачивать',
#  'выполнять',
#  'выражать',
#  'выражать столь',
#  'выражаться',
#  'выражаться нецензурный',
#  'выраженность',
#  'выраженность трупный',
#  'выраженный',
#  'вырез',
#  'вырывать',
#  'вырываться',
#  'высказывание',
#  'высказывать',
#  'высказывать претензия',
#  'высказывать угроза',
#  'высказываться',
#  'выслушивать',
#  'высокий',
#  'высоко',
#  'высота',
#  'высота собственный',
#  'выставлять',
#  'выступать',
#  'вытаскивать',
#  'вытирать',
#  'вытягивать',
#  'выхватывать',
#  'выход',
#  'выходить',
#  'выходить двор',
#  'выходить дом',
#  'выходить квартира',
#  'выходить комната',
#  'выходить кухня',
#  'выходить подъезд',
#  'выходить улица',
#  'выходной',
#  'выше',
#  'выше доказательство',
#  'выше обстоятельство',
#  'вышеизложенный',
#  'вышеописанный',
#  'вышеперечисленный',
#  'вышеприведенный',
#  'вышеприведенный доказательство',
#  'вышеуказанный',
#  'вышеуказанный квартира',
#  'вышеуказанный повреждение',
#  'выявлять',
#  'выявлять антиген',
#  'выяснять',
#  'выясняться',
#  'галлюцинация',
#  'гараж',
#  'гбуз',
#  'гематома',
#  'гемоторакс',
#  'генетический',
#  'генетический экспертиза',
#  'гибель',
#  'гистологический',
#  'гистологический исследование',
#  'глава',
#  'глаз',
#  'глубина',
#  'глубокий',
#  'глухой',
#  'говорить',
#  'говорить убивать',
#  'голень',
#  'голова',
#  'голова грудь',
#  'голова кровоподтек',
#  'голова кровь',
#  'голова лицо',
#  'голова наносить',
#  'голова область',
#  'голова потерпеть',
#  'голова причинять',
#  'голова рука',
#  'голова тело',
#  'голова труп',
#  'голова туловище',
#  'голова удар',
#  'голова шея',
#  'головной',
#  'головной мозг',
#  'голос',
#  'голубой',
#  'голубой цвет',
#  'голый',
#  'гореть',
#  'горизонтальный',
#  'горло',
#  'город',
#  'городской',
#  'городской прокурор',
#  'городской республика',
#  'городской течение',
#  'гортань',
#  'госпитализация',
#  'госпитализировать',
#  'гость',
#  'гость приходить',
#  'государственный',
#  'государственный обвинитель',
#  'государственный орган',
#  'государство',
#  'готовить',
#  'готовый',
#  'гражданин',
#  'гражданин российский',
#  'гражданин средний',
#  'гражданка',
#  'гражданский',
#  'гражданский иск',
#  'грамм',
#  'граница',
#  'громкий',
#  'громко',
#  'грохот',
#  'грубый',
#  'грубый нецензурный',
#  'грудина',
#  'грудной',
#  'грудной клетка',
#  'грудь',
#  'грудь живот',
#  'грудь слева',
#  'грудь справа',
#  'грудь удар',
#  'группа',
#  'группа кровь',
#  'групповой',
#  'групповой принадлежность',
#  'губа',
#  'гулять',
#  'давать',
#  'давать аналогичный',
#  'давать давать',
#  'давать деньги',
#  'давать добровольно',
#  'давать заседание',
#  'давать основание',
#  'давать подробный',
#  'давать предварительный',
#  'давать признательный',
#  'давать присутствие',
#  'давление',
#  'давление сторона',
#  'давность',
#  'давность наступление',
#  'давность образование',
#  'дактилоскопический',
#  'дактилоскопический экспертиза',
#  'далее',
#  'дальнейший',
#  'дальний',
#  'данные',
#  'данные гистологический',
#  'данные давать',
#  'данные данные',
#  'данные данный',
#  'данные допрос',
#  'данные заключение',
#  'данные заседание',
#  'данные качество',
#  'данные личность',
#  'данные медицинский',
#  'данные обвинять',
#  'данные повреждение',
#  'данные предварительный',
#  'данные протокол',
#  'данные ранее',
#  'данные следствие',
#  'данные судить',
#  'данный',
#  'данный вывод',
#  'данный давать',
#  'данный дело',
#  'данный дом',
#  'данный женщина',
#  'данный заключение',
#  'данный квартира',
#  'данный нож',
#  'данный обстоятельство',
#  'данный повреждение',
#  'данный предварительный',
#  'данный следственный',
#  'данный случай',
#  'данный телесный',
#  'данный травма',
#  'данный уголовный',
#  'данный факт',
#  'дата',
#  'дата дата',
#  'дата помнить',
#  'дата рождение',
#  'дача',
#  'дача заведомо',
#  'дача отказываться',
#  'дважды',
#  'дверной',
#  'дверной проем',
#  'дверь',
#  'дверь дом',
#  'дверь закрывать',
#  'дверь квартира',
#  'дверь ключ',
#  'дверь комната',
#  'дверь никто',
#  'дверь открывать',
#  'дверь увидеть',
#  'двигаться',
#  'движение',
#  'двое',
#  'двор',
#  'двор дом',
#  'двоюродный',
#  'двоюродный сестра',
#  'двусторонний',
#  'девушка',
#  'дежурный',
#  'дежурный омвд',
#  'дежурный часть',
#  'дежурство',
#  'действие',
#  'действие вид',
#  'действие заключение',
#  'действие квалифицировать',
#  'действие направлять',
#  'действие наступать',
#  'действие носить',
#  'действие отношение',
#  'действие потерпеть',
#  'действие предвидеть',
#  'действие причинять',
#  'действие руководить',
#  'действие тупой',
#  'действительность',
#  'действовать',
#  'действовать прямой',
#  'действовать умышленно',
#  'декабрь',
#  'делать',
#  'дело',
#  'дело апелляционный',
#  'дело вещественный',
#  'дело давать',
#  'дело данные',
#  'дело данный',
#  'дело доказательство',
#  'дело заключение',
#  'дело заявлять',
#  'дело иметься',
#  'дело исследовать',
#  'дело качество',
#  'дело обвинение',
#  'дело обстоятельство',
#  'дело основание',
#  'дело отношение',
#  'дело оценивать',
#  'дело потерпеть',
#  'дело приговор',
#  'дело приходить',
#  'дело протокол',
#  'дело рапорт',
#  'дело российский',
#  'дело следовать',
#  'дело совокупность',
#  'дело считать',
#  'дело устанавливать',
#  'дело число',
#  'дело экспертиза',
#  'денежный',
#  'денежный средство',
#  'деньги',
#  'деревня',
#  'деревянный',
#  'деревянный ручка',
#  'держать',
#  'держать нож',
#  'держать правый',
#  'держать рука',
#  'держаться',
#  'десяток',
#  'десяток минута',
#  'детализация',
#  'деталь',
#  'детский',
#  'детство',
#  'деяние',
#  'деяние настоящий',
#  'деяние подтверждаться',
#  'деяние признавать',
#  'деяние состояние',
#  'деяние страдать',
#  'деятельность',
#  'джинсовый',
#  'джинсы',
#  'диагноз',
#  'диван',
#  'диван комната',
#  'диван лежать',
#  'диван обнаруживать',
#  'диск',
#  'дислокация',
#  'диспансер',
#  'диспетчер',
#  'длина',
#  'длина клинок',
#  'длина раневой',
#  'длинный',
#  'длительность',
#  'длительный',
#  'длительный расстройство',
#  'дневной',
#  'днк',
#  'дно',
#  'добавлять',
#  'добровольно',
#  'добровольно сообщать',
#  'добровольный',
#  'добрый',
#  'добрый отзывчивый',
#  'добывать',
#  'доверять',
#  'довод',
#  'довод сторона',
#  'доводить',
#  'доводить конец',
#  'догнать',
#  'договариваться',
#  'доезжать',
#  'дождаться',
#  'дозваниваться',
#  'доказанность',
#  'доказанность вина',
#  'доказательство',
#  'доказательство виновность',
#  'доказательство дело',
#  'доказательство допрашивать',
#  'доказательство заключение',
#  'доказательство заседание',
#  'доказательство исследовать',
#  'доказательство находить',
#  'доказательство нож',
#  'доказательство оценивать',
#  'доказательство подтверждать',
#  'доказательство получать',
#  'доказательство потерпеть',
#  'доказательство представлять',
#  'доказательство признавать',
#  'доказательство приобщать',
#  'доказательство приходить',
#  'доказательство протокол',
#  'доказательство рапорт',
#  'доказательство следовать',
#  'доказательство совокупность',
#  'доказательство считать',
#  'доказательство уголовный',
#  'доказательство устанавливать',
#  'доказательство число',
#  'доказательство являться',
#  'доказывать',
#  'документ',
#  'долг',
#  'должностной',
#  'должность',
#  'должный',
#  'должный предвидеть',
#  'доля',
#  'доля левый',
#  'доля печень',
#  'доля правый',
#  'дом',
#  'дом вернуться',
#  'дом видеть',
#  'дом вместе',
#  'дом выходить',
#  'дом дом',
#  'дом зайти',
#  'дом мать',
#  'дом никто',
#  'дом обнаруживать',
#  'дом оставаться',
#  'дом пойти',
#  'дом последний',
#  'дом приходить',
#  'дом проживать',
#  'дом располагать',
#  'дом становиться',
#  'дом увидеть',
#  'дом улица',
#  'дома',
#  'дома примерно',
#  'домашний',
#  'домовладение',
#  'домой',
#  'домой вернуться',
#  'домой дом',
#  'домой ложиться',
#  'домой приезжать',
#  'домой примерно',
#  'домой приходить',
#  'домой состояние',
#  'домой становиться',
#  'домой увидеть',
#  'доноситься',
#  'допивать',
#  'дополнительно',
#  'дополнительный',
#  'дополнительный вид',
#  'дополнительный допрос',
#  'дополнительный осмотр',
#  'дополнять',
#  'дополнять друг',
#  'допрашивать',
#  'допрашивать заседание',
#  'допрашивать качество',
#  'допрашивать предварительный',
#  'допрос',
#  'допрос качество',
#  'допускать',
#  'допустимость',
#  'допустимость достоверность',
#  'допустимый',
#  'допустимый доказательство',
#  'допустимый достоверный',
#  'дорога',
#  'доска',
#  'досрочно',
#  'доставать',
#  'доставление',
#  'доставлять',
#  'доставлять отдел',
#  'достаточно',
#  'достаточность',
#  'достаточный',
#  'достаточный основание',
#  'достаточный разрешение',
#  'достаточный сила',
#  'достигать',
#  'достижение',
#  'достижение цель',
#  'достоверно',
#  'достоверно устанавливать',
#  'достоверность',
#  'достоверный',
#  'достоверный доказательство',
#  'достоверный допустимый',
#  'достоверный поскольку',
#  'достоверный совокупность',
#  'доступ',
#  'доступный',
#  'досудебный',
#  'доход',
#  'доход государство',
#  'доход федеральный',
#  'доходить',
#  'дочь',
#  'дочь проживать',
#  'драка',
#  'драться',
#  'друг',
#  'друг друг',
#  'дружеский',
#  'дружеский отношение',
#  'дружить',
#  'дуга',
#  'думать',
#  'душевный',
#  'душевный волнение',
#  'душить',
#  'дыхание',
#  'дыхательный',
#  'дыхательный путь',
#  'дышать',
#  'дядя',
#  'еда',
#  'единственный',
#  'единый',
#  'ездить',
#  'емкость',
#  'ехать',
#  'жалоба',
#  'жалоба осуждать',
#  'жалоба представление',
#  'жаловаться',
#  'ждать',
#  'желание',
#  'желать',
#  'желать наступление',
#  'железа',
#  'желтый',
#  'желтый цвет',
#  'желудочек',
#  'жена',
#  'женатый',
#  'женский',
#  'женщина',
#  'женщина лежать',
#  'женщина признак',
#  'живой',
#  'живой лицо',
#  'живот',
#  'живот удар',
#  'жидкий',
#  'жидкий кровь',
#  'жидкость',
#  'жизненно',
#  'жизненно орган',
#  'жизненно часть',
#  'жизненный',
#  'жилище',
#  'жилой',
#  'жилой дом',
#  'жилой комната',
#  'жилье',
#  'жировой',
#  'жировой клетчатка',
#  'житель',
#  'жительство',
#  'жительство характеризоваться',
#  'жить',
#  'жить вместе',
#  'забегать',
#  'забирать',
#  'заболевание',
#  'забор',
#  'забывать',
#  'заведомо',
#  'заведомо ложный',
#  'зависеть',
#  'зависимость',
#  'зависимость алкоголь',
#  'заводить',
#  'заглядывать',
#  'задавать',
#  ...]

# %%
with open("gbc_dv.pkl", 'rb') as file:
    dv = pickle.load(file)
    
with open("gbc_ipv.pkl", 'rb') as file:
    ipv = pickle.load(file)

# %%
import pandas as pd
pd.DataFrame(zip(cvect.get_feature_names(), list(dv.feature_importances_)), columns=['token', 'imp']).sort_values('imp', ascending=False).to_excel('words_dv.xlsx')

# %%
pd.DataFrame(zip(cvect.get_feature_names(), list(ipv.feature_importances_)), columns=['token', 'imp']).sort_values('imp', ascending=False).to_excel('words_ipv.xlsx')

# %% [markdown]
# Поймём направление прогноза с помощью более простых моделей

# %%
import pandas as pd
dv_words = pd.read_excel('words_dv.xlsx', index_col=0).set_index('token')
dv_words.head()
# Out:
#                  imp
# token
# подсудимая  0.045905
# ревность    0.044099
# хищение     0.042886
# скандал     0.025388
# ссора       0.024234

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, precision_score, f1_score

data = pd.read_excel('preprocessed_data_2018.xlsx', index_col=0).set_index('ID')
cvect = CountVectorizer(min_df=0.05, ngram_range=(1, 2)).fit(data['text_prep'])
matrix = cvect.transform(data['text_prep'])
td_matrix = pd.DataFrame(matrix.toarray(), index=data.index, columns=cvect.get_feature_names())
td_matrix.head()
# Out:
#                                   абонентский  абонентский номер  август  \
# ID
# 82060183bdf7472e85540c4370d3693c            0                  0       0
# 377054bb5594776bb30ff64c6ebcffb8            0                  0       0
# 6df614cdfd7d029cde776d52ed7932d2            0                  0       1
# 50593bc68988c7aae8f9f2f2bf243f8a            0                  0       0
# 54e009a196b97005a1b4d828670345e7            0                  0       0
#
#                                   автомашина  автомобиль  агрессивный  \
# ID
# 82060183bdf7472e85540c4370d3693c           0           0            1
# 377054bb5594776bb30ff64c6ebcffb8           0           0            0
# 6df614cdfd7d029cde776d52ed7932d2           0           0            2
# 50593bc68988c7aae8f9f2f2bf243f8a           0           0            0
# 54e009a196b97005a1b4d828670345e7           0           5            0
#
#                                   агрессия  адвокат  адвокатский  адекватно  \
# ID
# 82060183bdf7472e85540c4370d3693c         0        2            0          0
# 377054bb5594776bb30ff64c6ebcffb8         0        3            0          0
# 6df614cdfd7d029cde776d52ed7932d2         0        1            0          0
# 50593bc68988c7aae8f9f2f2bf243f8a         0        1            0          0
# 54e009a196b97005a1b4d828670345e7         0        1            0          0
#
#                                   ...  являться причина  являться родной  \
# ID                                ...
# 82060183bdf7472e85540c4370d3693c  ...                 0                1
# 377054bb5594776bb30ff64c6ebcffb8  ...                 0                0
# 6df614cdfd7d029cde776d52ed7932d2  ...                 0                0
# 50593bc68988c7aae8f9f2f2bf243f8a  ...                 0                0
# 54e009a196b97005a1b4d828670345e7  ...                 0                0
#
#                                   явный  ягодица  язык  якобы  январь  \
# ID
# 82060183bdf7472e85540c4370d3693c      0        0     0      0       0
# 377054bb5594776bb30ff64c6ebcffb8      0        0     0      0       0
# 6df614cdfd7d029cde776d52ed7932d2      0        0     0      0       0
# 50593bc68988c7aae8f9f2f2bf243f8a      0        0     0      0       3
# 54e009a196b97005a1b4d828670345e7      0        0     0      0       0
#
#                                   яремный  яремный вена  ящик
# ID
# 82060183bdf7472e85540c4370d3693c        0             0     0
# 377054bb5594776bb30ff64c6ebcffb8        0             0     0
# 6df614cdfd7d029cde776d52ed7932d2        0             0     0
# 50593bc68988c7aae8f9f2f2bf243f8a        0             0     0
# 54e009a196b97005a1b4d828670345e7        0             0     0
#
# [5 rows x 5522 columns]

# %%
td_matrix['DV'] = data['DV']
td_matrix['IPV'] = data['IPV']

y_dv = td_matrix['DV'].astype(int)
X_dv = td_matrix.drop(["DV", 'IPV'], axis=1)

y_ipv = td_matrix[td_matrix['IPV'].notna()]['IPV'].astype(int).replace({2: 0}) # 0 - родственник, 1 - партнер
X_ipv = td_matrix[td_matrix['IPV'].notna()].drop(["DV", 'IPV'], axis=1)
print(y_dv.shape, X_dv.shape, y_ipv.shape, X_ipv.shape)
# Out:
# (1632,) (1632, 5522) (1128,) (1128, 5522)

# %% [markdown]
# Модель DV

# %%
clf = LogisticRegression(random_state=42, max_iter=10000).fit(X_dv, y_dv)

# %%
coefs_dv = pd.DataFrame(zip(cvect.get_feature_names(), list(clf.coef_[0])), columns=['token', 'coef']).set_index('token')
coefs_dv.head()
# Out:
#                        coef
# token
# абонентский        0.032543
# абонентский номер -0.002778
# август             0.053216
# автомашина         0.064584
# автомобиль         0.013338

# %%
dv_words['coef'] = coefs_dv['coef']
dv_words['predict'] = dv_words['coef'].apply(lambda x: 'прогноз - ДН' if x > 0 else 'прогноз - НЕ ДН')
dv_words.head()
# Out:
#                  imp      coef          predict
# token
# подсудимая  0.045905 -0.270593  прогноз - НЕ ДН
# ревность    0.044099  0.370185     прогноз - ДН
# хищение     0.042886 -0.154486  прогноз - НЕ ДН
# скандал     0.025388  0.242490     прогноз - ДН
# ссора       0.024234  0.344314     прогноз - ДН

# %%
#dv_words.to_excel('words_dv.xlsx')

# %%
ipv_words = pd.read_excel('words_ipv.xlsx', index_col=0).set_index('token')
ipv_words.head()
# Out:
#                    imp
# token
# мать          0.333776
# подсудимая    0.072365
# ревность      0.070919
# бабушка       0.063138
# сожительница  0.041377

# %%
clf = LogisticRegression(random_state=42, max_iter=10000).fit(X_ipv, y_ipv)

# %%
coefs_ipv = pd.DataFrame(zip(cvect.get_feature_names(), list(clf.coef_[0])), columns=['token', 'coef']).set_index('token')
coefs_ipv.head()
# Out:
#                        coef
# token
# абонентский        0.008986
# абонентский номер  0.029857
# август            -0.121702
# автомашина         0.012726
# автомобиль         0.027747

# %%
ipv_words['coef'] = coefs_ipv['coef']
ipv_words['predict'] = ipv_words['coef'].apply(lambda x: 'прогноз - ПАРТНЕР' if x > 0 else 'прогноз - РОДСТВЕННИК')
ipv_words.head()
# Out:
#                    imp      coef                predict
# token
# мать          0.333776 -0.361695  прогноз - РОДСТВЕННИК
# подсудимая    0.072365 -0.298342  прогноз - РОДСТВЕННИК
# ревность      0.070919  0.213757      прогноз - ПАРТНЕР
# бабушка       0.063138 -0.214108  прогноз - РОДСТВЕННИК
# сожительница  0.041377  0.319381      прогноз - ПАРТНЕР

# %%
#ipv_words.to_excel('words_ipv.xlsx')

# %%
print(classification_report(y_train, gbc.predict(X_train)))
print(classification_report(y_test, gbc.predict(X_test))
